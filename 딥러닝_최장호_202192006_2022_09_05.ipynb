# %% [markdown]
# #### (연습 1)
# 𝐵𝑜𝑜𝑙𝑒𝑎𝑛 𝑂𝑅 / AND  구현하는 python program을 작성하시오

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import *

# %% [markdown]
# ### OR Gate

# %%
for i in [False, True]:
    for j in [False, True]:
        print('{} \tOR \t{} \t= \t{}'.format(i, j, i or j))
# Out:
# False 	OR 	False 	= 	False
# False 	OR 	True 	= 	True
# True 	OR 	False 	= 	True
# True 	OR 	True 	= 	True

# %% [markdown]
# ### AND Gate

# %%
for i in [False, True]:
    for j in [False, True]:
        print('{} \tAND \t{} \t= \t{}'.format(i, j, i and j))
# Out:
# False 	AND 	False 	= 	False
# False 	AND 	True 	= 	False
# True 	AND 	False 	= 	False
# True 	AND 	True 	= 	True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import *

# %% [markdown]
# # Relu

# %%
xx = np.linspace(-10, 10, 100)
plt.plot(xx, np.maximum(xx, 0))

plt.xlabel("$x$")
plt.ylabel("$ReLU(x)$")
plt.show()

# %%
x = np.linspace(-10, 10, 100)
plt.plot(x,np.array(x > 0, dtype = np.int))

plt.show()
# Out:
# C:\Users\kowm6\AppData\Local\Temp/ipykernel_25536/2833574910.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.plot(x,np.array(x > 0, dtype = np.int))

# %% [markdown]
# # 시그모이드

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

xx = np.linspace(-10, 10, 100)
plt.plot(xx, sigmoid(xx))

plt.xlabel("$x$")
plt.ylabel("$\sigma(x)$")
plt.show()

# %%
def D_sigmoid(x):
    return sigmoid(x) * (1 - sigmoid(x))

xx = np.linspace(-10, 10, 100)
plt.plot(xx, D_sigmoid(xx))

plt.show()

# %% [markdown]
# ## tanh

# %%
def tanh(x):
    return(np.exp(x) - np.exp(-x)) / (np.exp(x)+np.exp(-x))

xx = np.linspace(-10, 10, 100)
plt.plot(xx, tanh(xx))

plt.xlabel("$x$")
plt.ylabel("$\sigma(x)$")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def tanh(x):
    return(np.exp(x) - np.exp(-x)) / (np.exp(x)+np.exp(-x))

x = np.linspace(-10, 10, 100)
plt.plot(x, (1+tanh(x))*(1-tanh(x)))


plt.show()
